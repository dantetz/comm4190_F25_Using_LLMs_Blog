# %% [raw]
# ---
# title: "Airport Reviews"
# description: "I'm interested in seeing what LLM's think about differnet airport  "
# author: "Dante"
# date: "9/27/2025"
# categories:
#   - LLMs
#   - Learning
# ---
